# %%
x = 5
print(type(x))
#int
# Out:
# <class 'int'>

# %%
x = "Hello World"
print(type(x))
#str
# Out:
# <class 'str'>

# %%
x = 20.5
print(type(x))
#float
# Out:
# <class 'float'>

# %%
x = ["apple", "banana", "cherry"]
print(type(x))
#list
# Out:
# <class 'list'>

# %%
x = ("apple", "banana", "cherry")
print(type(x))
#tuple
# Out:
# <class 'tuple'>

# %%
x = {"name" : "John", "age" : 36}
print(type(x))
#dict
# Out:
# <class 'dict'>

# %%
x = True
print(type(x))
#bool
# Out:
# <class 'bool'>
